# %%
 Question 1: Read the Bike Details dataset into a Pandas DataFrame and display its
first 10 rows.

# %%
import pandas as pd

df = pd.read_csv("Bike Details.csv")
print(df.head(10))

# %% [markdown]
# Question 2: Check for missing values in all columns and describe your approach for
# handling them.
#
# Handling missing values (short):
#
# If few missing → drop rows: df.dropna()
# If important column → fill values:
# numeric: df['col'].fillna(df['col'].mean())
# categorical: df['col'].fillna(df['col'].mode()[0])

# %%
df.isnull().sum()

# %% [markdown]
# Question 3: Plot the distribution of selling prices using a histogram and describe the
# overall trend.

# %%
import matplotlib.pyplot as plt

plt.hist(df['Selling_Price'], bins=30)
plt.xlabel("Selling Price")
plt.ylabel("Frequency")
plt.title("Distribution of Selling Prices")
plt.show()

# %% [markdown]
# Question 4: Create a bar plot to visualize the average selling price for each seller_type
# and write one observation.

# %%
import matplotlib.pyplot as plt

df.groupby('seller_type')['Selling_Price'].mean().plot(kind='bar')
plt.ylabel("Average Selling Price")
plt.title("Avg Selling Price by Seller Type")
plt.show()

# %% [markdown]
# Question 5: Compute the average km_driven for each ownership type (1st owner,
# 2nd owner, etc.), and present the result as a bar plot.

# %%
import matplotlib.pyplot as plt

df.groupby('owner')['km_driven'].mean().plot(kind='bar')
plt.ylabel("Average KM Driven")
plt.title("Avg KM Driven by Owner Type")
plt.show()

# %% [markdown]
# Question 6: Use the IQR method to detect and remove outliers from the km_driven
# column. Show before-and-after summary statistic.

# %%
# Before summary
print("Before:\n", df['km_driven'].describe())

# IQR method
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df_clean = df[(df['km_driven'] >= lower) & (df['km_driven'] <= upper)]

# After summary
print("\nAfter:\n", df_clean['km_driven'].describe())

# %% [markdown]
# Question 7: Create a scatter plot of year vs. selling_price to explore the
# relationship between a bike's age and its price.

# %%
import matplotlib.pyplot as plt

plt.scatter(df['year'], df['Selling_Price'])
plt.xlabel("Year")
plt.ylabel("Selling Price")
plt.title("Year vs Selling Price")
plt.show()

# %% [markdown]
# Question 8: Convert the seller_type column into numeric format using one-hot
# encoding. Display the first 5 rows of the resulting DataFrame.
#
# Creates separate columns for each seller type
# Values become 0/1 (binary encoding)

# %%
df_encoded = pd.get_dummies(df, columns=['seller_type'])
print(df_encoded.head())

# %% [markdown]
# Question 9: Generate a heatmap of the correlation matrix for all numeric columns.
# What correlations stand out the most?
#
#
# year vs Selling_Price → strong positive correlation
# km_driven vs Selling_Price → negative correlation
# Older bikes (low year) tend to be cheaper and more driven

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Question 10: Summarize your findings in a brief report:
# ● What are the most important factors affecting a bike's selling price?
# ● Mention any data cleaning or feature engineering you performed.
#
#
# Year: Newer bikes have higher selling prices (strong positive impact)
# km_driven: Higher usage lowers price (negative impact)
# Owner type: First-owner bikes generally cost more than multi-owner bikes
# Seller type: Dealers tend to list higher-priced bikes than individuals
#
# 2. Data cleaning & feature engineering:
#
# Handled missing values using dropping or imputation (mean/mode)
# Removed outliers in km_driven using the IQR method
# Converted seller_type into numeric form using one-hot encoding
